# %%
import os
import json
import pandas as pd
import re

path = os.path.abspath("/group/ag_abi/seiler/IBF/")
pattern = re.compile(r"(\w+)_(\w+)<(\w+), (\w+)<\d+>, (\w+)>/(\d+)/(\d+)(?:/(\d+)/(\d+)){0,1}")

# %% [markdown]
# # Insert Benchmark Evaluation

# %%
filename = os.path.join(path, "insert.json")
with open(filename, "r") as f:
    x = json.load(f)

# %%
row_list = []
for benchmark in x['benchmarks']:
    row_dict = {}
    [test, spec, alphabet, strategy, bitvector, bins, k, ram, h] = re.match(pattern, benchmark['name']).groups()
    if ram is None:
        ram = int(4**int(k)*int(bins)/1024/1024/8)
    else:
        ram = int(2**int(ram)/1024/1024/8)
    if h is None:
        h = 1  
    time = "{0:,.2f}".format(benchmark['real_time']/10**9/60)
    size = "{0:,}".format(int(benchmark['Size']))
    row_dict['Function'] = test
    row_dict['BD'] = spec
    row_dict['Alphabet'] = alphabet
    row_dict['Strategy'] = strategy
    row_dict['Bitvector'] = bitvector
    row_dict['bins'] = bins
    row_dict['k'] = k
    row_dict['RAM'] = "{0:,}".format(ram)
    row_dict['h'] = h
    row_dict['Time'] = time
    row_dict['Size'] = size
    row_list.append(row_dict)

# %%
df = pd.DataFrame(row_list)

# %%
df = df[["Function",
         "BD",
         "Alphabet",
         "Strategy",
         "Bitvector",
         "bins",
         "k",
         "h",
         "RAM",
         "Size",
         "Time"]]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#       Function   BD Alphabet Strategy     Bitvector  bins   k  h      RAM  \
# 0   insertKmer  IBF      Dna   Normal  Uncompressed    64  19  3    1,024
# 1   insertKmer  IBF      Dna   Normal  Uncompressed    64  19  3    2,048
# 2   insertKmer  IBF      Dna   Normal  Uncompressed    64  19  3    4,096
# 3   insertKmer  IBF      Dna   Normal  Uncompressed    64  19  3    8,192
# 4   insertKmer  IBF      Dna   Normal  Uncompressed    64  19  3   16,384
# 5   insertKmer  IBF      Dna   Normal  Uncompressed   256  19  3    1,024
# 6   insertKmer  IBF      Dna   Normal  Uncompressed   256  19  3    2,048
# 7   insertKmer  IBF      Dna   Normal  Uncompressed   256  19  3    4,096
# 8   insertKmer  IBF      Dna   Normal  Uncompressed   256  19  3    8,192
# 9   insertKmer  IBF      Dna   Normal  Uncompressed   256  19  3   16,384
# 10  insertKmer  IBF      Dna   Normal  Uncompressed  1024  19  3    1,024
# 11  insertKmer  IBF      Dna   Normal  Uncompressed  1024  19  3    2,048
# 12  insertKmer  IBF      Dna   Normal  Uncompressed  1024  19  3    4,096
# 13  insertKmer  IBF      Dna   Normal  Uncompressed  1024  19  3    8,192
# 14  insertKmer  IBF      Dna   Normal  Uncompressed  1024  19  3   16,384
# 15  insertKmer  IBF      Dna   Normal  Uncompressed  8192  19  3    1,024
# 16  insertKmer  IBF      Dna   Normal  Uncompressed  8192  19  3    2,048
# 17  insertKmer  IBF      Dna   Normal  Uncompressed  8192  19  3    4,096
# 18  insertKmer  IBF      Dna   Normal  Uncompressed  8192  19  3    8,192
# 19  insertKmer  IBF      Dna   Normal  Uncompressed  8192  19  3   16,384
# 20  insertKmer  IBF      Dna   Normal    Compressed    64  19  3    1,024
# 21  insertKmer  IBF      Dna   Normal    Compressed    64  19  3    2,048
# 22  insertKmer  IBF      Dna   Normal    Compressed    64  19  3    4,096
# 23  insertKmer  IBF      Dna   Normal    Compressed    64  19  3    8,192
# 24  insertKmer  IBF      Dna   Normal    Compressed    64  19  3   16,384
# 25  insertKmer  IBF      Dna   Normal    Compressed   256  19  3    1,024
# 26  insertKmer  IBF      Dna   Normal    Compressed   256  19  3    2,048
# 27  insertKmer  IBF      Dna   Normal    Compressed   256  19  3    4,096
# 28  insertKmer  IBF      Dna   Normal    Compressed   256  19  3    8,192
# 29  insertKmer  IBF      Dna   Normal    Compressed   256  19  3   16,384
# 30  insertKmer  IBF      Dna   Normal    Compressed  1024  19  3    1,024
# 31  insertKmer  IBF      Dna   Normal    Compressed  1024  19  3    2,048
# 32  insertKmer  IBF      Dna   Normal    Compressed  1024  19  3    4,096
# 33  insertKmer  IBF      Dna   Normal    Compressed  1024  19  3    8,192
# 34  insertKmer  IBF      Dna   Normal    Compressed  1024  19  3   16,384
# 35  insertKmer  IBF      Dna   Normal    Compressed  8192  19  3    1,024
# 36  insertKmer  IBF      Dna   Normal    Compressed  8192  19  3    2,048
# 37  insertKmer  IBF      Dna   Normal    Compressed  8192  19  3    4,096
# 38  insertKmer  IBF      Dna   Normal    Compressed  8192  19  3    8,192
# 39  insertKmer  IBF      Dna   Normal    Compressed  8192  19  3   16,384
# 40  insertKmer   DA      Dna   Normal  Uncompressed    64  10  1        8
# 41  insertKmer   DA      Dna   Normal  Uncompressed    64  11  1       32
# 42  insertKmer   DA      Dna   Normal  Uncompressed    64  12  1      128
# 43  insertKmer   DA      Dna   Normal  Uncompressed    64  13  1      512
# 44  insertKmer   DA      Dna   Normal  Uncompressed    64  14  1    2,048
# 45  insertKmer   DA      Dna   Normal  Uncompressed    64  15  1    8,192
# 46  insertKmer   DA      Dna   Normal  Uncompressed   256  10  1       32
# 47  insertKmer   DA      Dna   Normal  Uncompressed   256  11  1      128
# 48  insertKmer   DA      Dna   Normal  Uncompressed   256  12  1      512
# 49  insertKmer   DA      Dna   Normal  Uncompressed   256  13  1    2,048
# 50  insertKmer   DA      Dna   Normal  Uncompressed   256  14  1    8,192
# 51  insertKmer   DA      Dna   Normal  Uncompressed   256  15  1   32,768
# 52  insertKmer   DA      Dna   Normal  Uncompressed  1024  10  1      128
# 53  insertKmer   DA      Dna   Normal  Uncompressed  1024  11  1      512
# 54  insertKmer   DA      Dna   Normal  Uncompressed  1024  12  1    2,048
# 55  insertKmer   DA      Dna   Normal  Uncompressed  1024  13  1    8,192
# 56  insertKmer   DA      Dna   Normal  Uncompressed  1024  14  1   32,768
# 57  insertKmer   DA      Dna   Normal  Uncompressed  1024  15  1  131,072
# 46       32   2.96
# 47      128   4.60
# 48      512   5.11
# 49    2,048   5.36
# 50    8,192   5.00
# 51   32,768   6.71
# 52      128   4.86
# 53      512   5.22
# 54    2,048   5.40
# 55    8,192   5.81
# 56   32,768   6.36
# 57  131,072   9.10
# 58    1,024  24.97
# 59    4,096  16.25
# 60   16,384   9.58
# 61   65,536  11.57
# 62       27   9.03
# 63      110   2.96
# 64      437   4.64
# 65    1,354   5.46
# 66    2,552   5.87
# 67    3,732   6.77
# 68      110   9.62
# 69      437   4.79
# 70    1,354   5.46
# 71    2,551   5.80
# 72    3,732   6.68
# 73    1,780   8.64
# 74      437  11.66
# 75    1,353   5.40
# 76    2,551   5.84
# 77    3,730   7.32
# 78    1,779   8.85
# 79      606  10.61
# 80    1,934  26.66
# 81    3,152  17.65
# 82    2,905  18.53
# 83    1,051  18.58

# %%
df.to_csv(os.path.join(path, "insertBenchmark.tsv"), sep='\t', index=False)

# %% [markdown]
# # Select Benchmark Evaluation

# %%
filename = os.path.join(path, "select.json")
with open(filename, "r") as f:
    x = json.load(f)

# %%
row_list = []
for benchmark in x['benchmarks']:
    row_dict = {}
    [test, spec, alphabet, strategy, bitvector, bins, k, ram, h] = re.match(pattern, benchmark['name']).groups()
    if ram is None:
        ram = int(4**int(k)*int(bins)/1024/1024/8)
    else:
        ram = int(2**int(ram)/1024/1024/8)
    if h is None:
        h = 1  
    #time = round(benchmark['real_time']/10**9,2)
    #size = int(benchmark['Size'])
    row_dict['Full Time'] = "{0:,.2f}".format(benchmark['fullTime'])
    row_dict['load BD'] = "{0:,.2f}".format(benchmark['loadingTime'])
    row_dict['load Reads'] = "{0:,.2f}".format(benchmark['ioTime'])
    row_dict['sum Select'] = "{0:,.2f}".format(benchmark['selectTime'])
    row_dict['avg Select'] = "{0:,.2f}".format(benchmark['selectTime'] / 32)
    row_dict['Threads'] = 32
    row_dict['TP'] = "{0:,}".format(int(benchmark['TP']))
    row_dict['FN'] = "{0:,}".format(int(benchmark['FN']))
    row_dict['FP'] = "{0:,}".format(int(benchmark['FP']))
    row_dict['P'] = "{0:,}".format(int(benchmark['P']))
    row_dict['readNo'] = "{0:,}".format(int(benchmark['readNo']))
    row_dict['Absolute Verifications'] = "{0:,}".format(int(benchmark['verifications']))
    row_dict['Verifications per read'] = "{0:,.2f}".format(benchmark['Verifications'])
    row_dict['Sensitivity'] = benchmark['Sensitivity']
    row_dict['Precision'] = benchmark['Precision']
    row_dict['FNR'] = "{0:,.2f}".format(benchmark['FNR'])
    row_dict['FDR'] = "{0:,.2f}".format(benchmark['FDR'])
    row_dict['Function'] = test
    row_dict['BD'] = spec
    row_dict['Alphabet'] = alphabet
    row_dict['Strategy'] = strategy
    row_dict['Bitvector'] = bitvector
    row_dict['bins'] = bins
    row_dict['k'] = k
    row_dict['RAM'] = "{0:,}".format(int(ram))
    row_dict['h'] = h
    #row_dict['Time'] = time
    #row_dict['Size'] = size
    row_list.append(row_dict)

# %%
df = pd.DataFrame(row_list)

# %%
df = df[["Function",
         "BD",
         "Alphabet",
         "Strategy",
         "Bitvector",
         "bins",
         "k",
         "h",
         "RAM",
         "Full Time",
         "load BD",
         "load Reads",
         "sum Select",
         "avg Select",
         "TP",
         "FN",
         "FP",
         "P",
         "readNo",
         "Absolute Verifications",
         "Verifications per read",
         "Sensitivity",
         "Precision",
         "FNR",
         "FDR", 
         ]]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#    Function   BD Alphabet Strategy     Bitvector  bins   k  h      RAM  \
# 0    select  IBF      Dna   Normal  Uncompressed    64  19  3    1,024
# 1    select  IBF      Dna   Normal  Uncompressed    64  19  3    2,048
# 2    select  IBF      Dna   Normal  Uncompressed    64  19  3    4,096
# 3    select  IBF      Dna   Normal  Uncompressed    64  19  3    8,192
# 4    select  IBF      Dna   Normal  Uncompressed    64  19  3   16,384
# 5    select  IBF      Dna   Normal  Uncompressed   256  19  3    1,024
# 6    select  IBF      Dna   Normal  Uncompressed   256  19  3    2,048
# 7    select  IBF      Dna   Normal  Uncompressed   256  19  3    4,096
# 8    select  IBF      Dna   Normal  Uncompressed   256  19  3    8,192
# 9    select  IBF      Dna   Normal  Uncompressed   256  19  3   16,384
# 10   select  IBF      Dna   Normal  Uncompressed  1024  19  3    1,024
# 11   select  IBF      Dna   Normal  Uncompressed  1024  19  3    2,048
# 12   select  IBF      Dna   Normal  Uncompressed  1024  19  3    4,096
# 13   select  IBF      Dna   Normal  Uncompressed  1024  19  3    8,192
# 14   select  IBF      Dna   Normal  Uncompressed  1024  19  3   16,384
# 15   select  IBF      Dna   Normal  Uncompressed  8192  19  3    1,024
# 16   select  IBF      Dna   Normal  Uncompressed  8192  19  3    2,048
# 17   select  IBF      Dna   Normal  Uncompressed  8192  19  3    4,096
# 18   select  IBF      Dna   Normal  Uncompressed  8192  19  3    8,192
# 19   select  IBF      Dna   Normal  Uncompressed  8192  19  3   16,384
# 20   select  IBF      Dna   Normal    Compressed    64  19  3    1,024
# 21   select  IBF      Dna   Normal    Compressed    64  19  3    2,048
# 22   select  IBF      Dna   Normal    Compressed    64  19  3    4,096
# 23   select  IBF      Dna   Normal    Compressed    64  19  3    8,192
# 24   select  IBF      Dna   Normal    Compressed    64  19  3   16,384
# 25   select  IBF      Dna   Normal    Compressed   256  19  3    1,024
# 26   select  IBF      Dna   Normal    Compressed   256  19  3    2,048
# 27   select  IBF      Dna   Normal    Compressed   256  19  3    4,096
# 28   select  IBF      Dna   Normal    Compressed   256  19  3    8,192
# 29   select  IBF      Dna   Normal    Compressed   256  19  3   16,384
# 30   select  IBF      Dna   Normal    Compressed  1024  19  3    1,024
# 31   select  IBF      Dna   Normal    Compressed  1024  19  3    2,048
# 32   select  IBF      Dna   Normal    Compressed  1024  19  3    4,096
# 33   select  IBF      Dna   Normal    Compressed  1024  19  3    8,192
# 34   select  IBF      Dna   Normal    Compressed  1024  19  3   16,384
# 35   select  IBF      Dna   Normal    Compressed  8192  19  3    1,024
# 36   select  IBF      Dna   Normal    Compressed  8192  19  3    2,048
# 37   select  IBF      Dna   Normal    Compressed  8192  19  3    4,096
# 38   select  IBF      Dna   Normal    Compressed  8192  19  3    8,192
# 39   select  IBF      Dna   Normal    Compressed  8192  19  3   16,384
# 40   select   DA      Dna   Normal  Uncompressed    64  10  1        8
# 41   select   DA      Dna   Normal  Uncompressed    64  11  1       32
# 42   select   DA      Dna   Normal  Uncompressed    64  12  1      128
# 43   select   DA      Dna   Normal  Uncompressed    64  13  1      512
# 44   select   DA      Dna   Normal  Uncompressed    64  14  1    2,048
# 45   select   DA      Dna   Normal  Uncompressed    64  15  1    8,192
# 46   select   DA      Dna   Normal  Uncompressed   256  10  1       32
# 47   select   DA      Dna   Normal  Uncompressed   256  11  1      128
# 48   select   DA      Dna   Normal  Uncompressed   256  12  1      512
# 49   select   DA      Dna   Normal  Uncompressed   256  13  1    2,048
# 50   select   DA      Dna   Normal  Uncompressed   256  14  1    8,192
# 51   select   DA      Dna   Normal  Uncompressed   256  15  1   32,768
# 52   select   DA      Dna   Normal  Uncompressed  1024  10  1      128
# 53   select   DA      Dna   Normal  Uncompressed  1024  11  1      512
# 54   select   DA      Dna   Normal  Uncompressed  1024  12  1    2,048
# 55   select   DA      Dna   Normal  Uncompressed  1024  13  1    8,192
# 56   select   DA      Dna   Normal  Uncompressed  1024  14  1   32,768
# 57   select   DA      Dna   Normal  Uncompressed  1024  15  1  131,072
# 58   select   DA      Dna   Normal  Uncompressed  8192  10  1    1,024
# 59   select   DA      Dna   Normal  Uncompressed  8192  11  1    4,096
# 60   select   DA      Dna   Normal  Uncompressed  8192  12  1   16,384
# 61   select   DA      Dna   Normal  Uncompressed  8192  13  1   65,536
# 62   select   DA      Dna   Normal    Compressed    64  10  1        8
# 63   select   DA      Dna   Normal    Compressed    64  11  1       32
# 64   select   DA      Dna   Normal    Compressed    64  12  1      128
# 65   select   DA      Dna   Normal    Compressed    64  13  1      512
# 66   select   DA      Dna   Normal    Compressed    64  14  1    2,048
# 67   select   DA      Dna   Normal    Compressed    64  15  1    8,192
# 68   select   DA      Dna   Normal    Compressed   256  10  1       32
# 69   select   DA      Dna   Normal    Compressed   256  11  1      128
# 70   select   DA      Dna   Normal    Compressed   256  12  1      512
# 71   select   DA      Dna   Normal    Compressed   256  13  1    2,048
# 72   select   DA      Dna   Normal    Compressed   256  14  1    8,192
# 73   select   DA      Dna   Normal    Compressed   256  15  1   32,768
# 74   select   DA      Dna   Normal    Compressed  1024  10  1      128
# 75   select   DA      Dna   Normal    Compressed  1024  11  1      512
# 76   select   DA      Dna   Normal    Compressed  1024  12  1    2,048
# 77   select   DA      Dna   Normal    Compressed  1024  13  1    8,192
# 78   select   DA      Dna   Normal    Compressed  1024  14  1   32,768
# 79   select   DA      Dna   Normal    Compressed  1024  15  1  131,072
# 2             192      1,048,768  1,048,576              1,048,768
# 3             189      1,048,765  1,048,576              1,048,765
# 4             189      1,048,765  1,048,576              1,048,765
# 5     267,188,388    268,236,964  1,048,576            268,236,964
# 6          66,925      1,115,501  1,048,576              1,115,501
# 7           2,041      1,050,617  1,048,576              1,050,617
# 8           2,038      1,050,614  1,048,576              1,050,614
# 9           2,040      1,050,616  1,048,576              1,050,616
# 10  1,071,887,885  1,072,936,461  1,048,576          1,072,936,461
# 11        252,948      1,301,524  1,048,576              1,301,524
# 12              0      1,048,576  1,048,576              1,048,576
# 13              0      1,048,576  1,048,576              1,048,576
# 14              0      1,048,576  1,048,576              1,048,576
# 15  8,582,354,925  8,583,403,501  1,048,576          8,583,403,501
# 16      2,003,348      3,051,924  1,048,576              3,051,924
# 17              0      1,048,576  1,048,576              1,048,576
# 18              0      1,048,576  1,048,576              1,048,576
# 19              0      1,048,576  1,048,576              1,048,576
# 20     66,010,749     67,059,325  1,048,576             67,059,325
# 21         16,647      1,065,223  1,048,576              1,065,223
# 22            192      1,048,768  1,048,576              1,048,768
# 23            189      1,048,765  1,048,576              1,048,765
# 24            126        702,091  1,048,576                702,091
# 25    267,188,387    268,236,963  1,048,576            268,236,963
# 26         66,925      1,115,501  1,048,576              1,115,501
# 27          2,039      1,050,615  1,048,576              1,050,615
# 28          2,040      1,050,616  1,048,576              1,050,616
# 29          1,021        703,981  1,048,576                703,981
# 30  1,071,887,885  1,072,936,461  1,048,576          1,072,936,461
# 31        252,948      1,301,524  1,048,576              1,301,524
# 32              0      1,048,576  1,048,576              1,048,576
# 33              0      1,048,576  1,048,576              1,048,576
# 34              0        702,724  1,048,576                702,724
# 35  8,582,354,925  8,583,403,501  1,048,576          8,583,403,501
# 36      2,003,348      3,051,924  1,048,576              3,051,924
# 37              0      1,048,576  1,048,576              1,048,576
# 38              0      1,048,576  1,048,576              1,048,576
# 39              0        702,020  1,048,576                702,020
# 40     66,060,288     67,108,864  1,048,576             67,108,864
# 41     66,060,288     67,108,864  1,048,576             67,108,864
# 42     66,060,288     67,108,864  1,048,576             67,108,864
# 43     59,963,048     61,011,624  1,048,576             61,011,624
# 44            359      1,048,935  1,048,576              1,048,935
# 45            189      1,048,765  1,048,576              1,048,765
# 46    267,386,880    268,435,456  1,048,576            268,435,456
# 47    267,386,880    268,435,456  1,048,576            268,435,456
# 48    203,816,245    204,864,821  1,048,576            204,864,821
# 49          2,094      1,050,670  1,048,576              1,050,670
# 50          2,040      1,050,616  1,048,576              1,050,616
# 51          2,040      1,050,616  1,048,576              1,050,616
# 52  1,072,693,248  1,073,741,824  1,048,576          1,073,741,824
# 53    578,194,812    579,243,388  1,048,576            579,243,388
# 54              7      1,048,583  1,048,576              1,048,583
# 55              0      1,048,576  1,048,576              1,048,576
# 56              0      1,048,576  1,048,576              1,048,576
# 57              0      1,048,576  1,048,576              1,048,576
# 58        129,050      1,177,626  1,048,576              1,177,626
# 59              0      1,048,576  1,048,576              1,048,576
# 60              0      1,048,576  1,048,576              1,048,576
# 61              0      1,048,576  1,048,576              1,048,576
# 62     66,060,288     67,108,864  1,048,576             67,108,864
# 63     66,060,288     67,108,864  1,048,576             67,108,864
# 64     66,060,288     67,108,864  1,048,576             67,108,864
# 65     59,963,046     61,011,622  1,048,576             61,011,622
# 66            359      1,048,935  1,048,576              1,048,935
# 67            189      1,048,765  1,048,576              1,048,765
# 68    267,386,880    268,435,456  1,048,576            268,435,456
# 69    267,386,880    268,435,456  1,048,576            268,435,456
# 70    203,816,243    204,864,819  1,048,576            204,864,819
# 71          2,092      1,050,668  1,048,576              1,050,668
# 72          2,040      1,050,616  1,048,576              1,050,616
# 73              0            107  1,048,576                    107
# 74  1,072,693,248  1,073,741,824  1,048,576          1,073,741,824
# 75    578,194,812    579,243,388  1,048,576            579,243,388
# 76              7      1,048,583  1,048,576              1,048,583
# 77              0      1,048,576  1,048,576              1,048,576
# 78              0              9  1,048,576                      9
# 79              0              0  1,048,576                      0
# 80        129,050      1,177,626  1,048,576              1,177,626
# 81              0      1,048,576  1,048,576              1,048,576
# 82              0        104,854  1,048,576                104,854
# 83              0              0  1,048,576                      0
#
#    Verifications per read  Sensitivity  Precision   FNR   FDR
# 0                   63.95     1.000000   0.015637  0.00  0.98
# 1                    1.02     1.000000   0.984372  0.00  0.02
# 2                    1.00     1.000000   0.999817  0.00  0.00
# 3                    1.00     1.000000   0.999820  0.00  0.00
# 4                    1.00     1.000000   0.999820  0.00  0.00
# 5                  255.81     1.000000   0.003909  0.00  1.00
# 6                    1.06     1.000000   0.940005  0.00  0.06
# 7                    1.00     1.000000   0.998057  0.00  0.00
# 8                    1.00     1.000000   0.998060  0.00  0.00
# 9                    1.00     1.000000   0.998058  0.00  0.00
# 10               1,023.23     1.000000   0.000977  0.00  1.00
# 11                   1.24     1.000000   0.805652  0.00  0.19
# 12                   1.00     1.000000   1.000000  0.00  0.00
# 13                   1.00     1.000000   1.000000  0.00  0.00
# 14                   1.00     1.000000   1.000000  0.00  0.00
# 15               8,185.77     1.000000   0.000122  0.00  1.00
# 16                   2.91     1.000000   0.343579  0.00  0.66
# 17                   1.00     1.000000   1.000000  0.00  0.00
# 18                   1.00     1.000000   1.000000  0.00  0.00
# 19                   1.00     1.000000   1.000000  0.00  0.00
# 20                  63.95     1.000000   0.015637  0.00  0.98
# 21                   1.02     1.000000   0.984372  0.00  0.02
# 22                   1.00     1.000000   0.999817  0.00  0.00
# 23                   1.00     1.000000   0.999820  0.00  0.00
# 24                   0.67     0.669445   0.999819  0.33  0.00
# 25                 255.81     1.000000   0.003909  0.00  1.00
# 26                   1.06     1.000000   0.940005  0.00  0.06
# 27                   1.00     1.000000   0.998059  0.00  0.00
# 28                   1.00     1.000000   0.998058  0.00  0.00
# 29                   0.67     0.670395   0.998550  0.33  0.00
# 30               1,023.23     1.000000   0.000977  0.00  1.00
